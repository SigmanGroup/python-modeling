# %%
# !git branch
# Out:
# * anna
#   master

# %%
pwd
# Out:
# '/Users/annabell/UofU/Sigman/python-modeling/demo'

# %% [markdown]
# # Reading Excel Files into Pandas Dataframes

# %% [markdown]
# ## Get data using "single file" as function (no changes from original file)

# %%
from old_exe_reader import prev_single_file_reader
prev_method = prev_single_file_reader()

# %% [markdown]
# ## New File Reader Options (Simplified Implementation)

# %%
from reading_data import read_excel_file
methods = read_excel_file()

# %% [markdown]
# ### Simply read file (no custom rows/columns)

# %%
methods.read_excel_file("../model_oct_bothsubs"+".xlsx")

# %%
methods.data
# Out:
#            0                                       Unnamed: 1             1  \
# 3         ID                                           SMILES  s2_1h_%yield
# 4         ID                                           SMILES  s2_1h_%yield
# 5         L1     c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 6         L2   COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 7         L3  COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# ..       ...                                              ...           ...
# 68  test_040                                              NaN             0
# 69  test_041                                              NaN             0
# 70  test_042                                              NaN             0
# 71  test_043                                              NaN             0
# 72  test_044                                              NaN             0
#
# ...

# %% [markdown]
# ### Read excel with custom sheet name and header

# %%
methods.read_excel_file("../model_oct_bothsubs"+".xlsx", "bubbleplot", 5)

# %%
methods.data
# Out:
#           ID                                             SMILES  s2_1h_%yield  \
# 0         L1       c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1         L2     COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2         L3    COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# 3         L4       c1cc(c(c(c1)S(=O)(=O)N2CCOCC2)NC(=O)C(=O)O)F            17
# 4         L5  CN1CCN(CC1)S(=O)(=O)c2cccc(c2NC(=O)C(=O)[O-])F...             8
# ..       ...                                                ...           ...
# 63  test_040                                                NaN             0
# 64  test_041                                                NaN             0
# 65  test_042                                                NaN             0
# 66  test_043                                                NaN             0
# 67  test_044                                                NaN             0
#
# ...

# %% [markdown]
# ### Read excel with custom sheet name and header, with row span [0,24]

# %%
methods.read_excel_file("../model_oct_bothsubs"+".xlsx", "bubbleplot", 5, 0, 24)

# %%
methods.df.shape
# Out:
# (24, 11)

# %%
methods.df.head()
# Out:
#    ID                                             SMILES  s2_1h_%yield  \
# 0  L1       c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1  L2     COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2  L3    COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# 3  L4       c1cc(c(c(c1)S(=O)(=O)N2CCOCC2)NC(=O)C(=O)O)F            17
# 4  L5  CN1CCN(CC1)S(=O)(=O)c2cccc(c2NC(=O)C(=O)[O-])F...             8
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
# 3            57.666667             89             7            35.500000
# 4            48.333333             83             3            21.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# ...

# %%
data = methods.data #to use in later demo

# %% [markdown]
# ### Read excel with custom sheet name and header, with row span [0,24] and column span [0,2]

# %%
header_col = 5
rows_start = 0
rows_stop = 24
cols_start = 0
cols_stop = 2

# %%
methods.read_excel_file("../model_oct_bothsubs"+".xlsx", "bubbleplot", header_col, rows_start, rows_stop, cols_start, cols_stop)

# %%
methods.data.shape
# Out:
# (68, 11)

# %%
methods.data.head()
# Out:
#    ID                                             SMILES  s2_1h_%yield  \
# 0  L1       c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1  L2     COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2  L3    COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# 3  L4       c1cc(c(c(c1)S(=O)(=O)N2CCOCC2)NC(=O)C(=O)O)F            17
# 4  L5  CN1CCN(CC1)S(=O)(=O)c2cccc(c2NC(=O)C(=O)[O-])F...             8
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
# 3            57.666667             89             7            35.500000
# 4            48.333333             83             3            21.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# ...

# %% [markdown]
# ## Read more-than one file (separate files)

# %%
# untested
# methods.read_two_excel_files()

# %% [markdown]
# # Preselecting Data for Models

# %%
from preprocessing import data_prep

# %%
data.head(3)
# Out:
#    ID                                           SMILES  s2_1h_%yield  \
# 0  L1     c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1  L2   COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2  L3  COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# 0             69        0           -0.59232                 -0.89851
# 1             65        0           -0.58780                 -0.90730
# 2             57        0           -0.57818                 -0.90199

# %%
Y_labels = data['ID']
X_labels = data.columns
X = data.loc[:, data.columns != 'ID']
Y = data['s2_1h_%yield']

# %% [markdown]
# ### read in the data, no changes

# %%
preselct = data_prep(X, Y, X_labels, Y_labels)
preselct.print_result()
# Out:
# Shape X: (68, 10)
# Shape y: (68,)
# Shape labels: (68,)

# %% [markdown]
# #### get_curr_data
#
# This method allows you to save a copy of your data after you made changes to it. It is not necessay to use this method for the original dataset, though, because that copy is saved in the class.

# %%
X, Y = preselct.get_curr_data()

# %%
X.head()
# Out:
#                                               SMILES  s2_1h_%yield  \
# 0       c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1     COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2    COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# 3       c1cc(c(c(c1)S(=O)(=O)N2CCOCC2)NC(=O)C(=O)O)F            17
# 4  CN1CCN(CC1)S(=O)(=O)c2cccc(c2NC(=O)C(=O)[O-])F...             8
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
# 3            57.666667             89             7            35.500000
# 4            48.333333             83             3            21.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# ...

# %%
Y.head()
# Out:
# 0    18
# 1     9
# 2     6
# 3    17
# 4     8
# Name: s2_1h_%yield, dtype: int64

# %% [markdown]
# ### use preselect options

# %% [markdown]
# #### reset_data
# This method allows the user to revert to the original data before using any preselect methods

# %%
#this reverts your changes back to the original dataset
preselct.reset_data()

# %% [markdown]
# #### view current data after reset
# (lower-case x is the current data with applied preselect methods)

# %%
preselct.x.head()
# Out:
#                                               SMILES  s2_1h_%yield  \
# 0       c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1     COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2    COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# 3       c1cc(c(c(c1)S(=O)(=O)N2CCOCC2)NC(=O)C(=O)O)F            17
# 4  CN1CCN(CC1)S(=O)(=O)c2cccc(c2NC(=O)C(=O)[O-])F...             8
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
# 3            57.666667             89             7            35.500000
# 4            48.333333             83             3            21.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# ...

# %% [markdown]
# #### If you want to compare to the original dataset, you can access the original directly
# (upper-case X is the original data before applied preselect methods)

# %%
preselct.X.head()
# Out:
#                                               SMILES  s2_1h_%yield  \
# 0       c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1     COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2    COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
# 3       c1cc(c(c(c1)S(=O)(=O)N2CCOCC2)NC(=O)C(=O)O)F            17
# 4  CN1CCN(CC1)S(=O)(=O)c2cccc(c2NC(=O)C(=O)[O-])F...             8
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
# 3            57.666667             89             7            35.500000
# 4            48.333333             83             3            21.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# ...

# %% [markdown]
# ### manipulating Y

# %%
preselct.y
# Out:
# 0     18
# 1      9
# 2      6
# 3     17
# 4      8
#       ..
# 63     0
# 64     0
# 65     0
# 66     0
# 67     0
# Name: s2_1h_%yield, Length: 68, dtype: int64

# %% [markdown]
# #### get_y_exp

# %%
preselct.get_y_exp()
preselct.y
# Out:
# 0     6.565997e+07
# 1     8.103084e+03
# 2     4.034288e+02
# 3     2.415495e+07
# 4     2.980958e+03
#           ...
# 63    1.000000e+00
# 64    1.000000e+00
# 65    1.000000e+00
# 66    1.000000e+00
# 67    1.000000e+00
# Name: s2_1h_%yield, Length: 68, dtype: float64

# %% [markdown]
# #### get_y_log
#
# The function's default is to add a very number to any 0 value.
# You can also specify that you want to remove any row with zeros in it by setting remove_y_zeros to True.

# %%
preselct.get_y_log(remove_y_zeros = False)
preselct.y
# Out:
# 0     18.0000
# 1      9.0000
# 2      6.0000
# 3     17.0000
# 4      8.0000
#        ...
# 63     0.0001
# 64     0.0001
# 65     0.0001
# 66     0.0001
# 67     0.0001
# Name: s2_1h_%yield, Length: 68, dtype: float64

# %% [markdown]
# #### absolute value

# %%
preselct.get_y_abs()
preselct.y
# Out:
# 0     18.0000
# 1      9.0000
# 2      6.0000
# 3     17.0000
# 4      8.0000
#        ...
# 63     0.0001
# 64     0.0001
# 65     0.0001
# 66     0.0001
# 67     0.0001
# Name: s2_1h_%yield, Length: 68, dtype: float64

# %% [markdown]
# #### exclude column with name
#
# This method takes a list of one or more column names and removes them from the dataframe

# %%
preselct.x.head(3)
# Out:
#                                             SMILES  s2_1h_%yield  \
# 0     c1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F            18
# 1   COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)F             9
# 2  COc1cc(c(c(c1)S(=O)(=O)N2CCCCC2)NC(=O)C(=O)O)OC             6
#
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# 0             69        0           -0.59232                 -0.89851
# 1             65        0           -0.58780                 -0.90730
# 2             57        0           -0.57818                 -0.90199

# %%
preselct.drop_cols_names('SMILES') # you can add a list of names

# %%
preselct.x.head(3)
# Out:
#    s2_1h_%yield  s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  \
# 0            18            55.500000             92             6
# 1             9            36.333333             92             6
# 2             6            19.666667             73             2
#
#    s4_3.5h_%yield(avg)  s4_21h_%yield  virtual  nbo_N_oxamide_max  \
# 0            27.666667             69        0           -0.59232
# 1            27.000000             65        0           -0.58780
# 2            11.333333             57        0           -0.57818
#
#    nbo_aryl_sub_=O_max_max
# 0                 -0.89851
# 1                 -0.90730
# 2                 -0.90199

# %% [markdown]
# #### exclude column at index
#
# This method takes a list of one or more column indices and removes them from the dataframe

# %%
preselct.drop_cols_indices(0)

# %%
preselct.x.head(3)
# Out:
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# 0             69        0           -0.59232                 -0.89851
# 1             65        0           -0.58780                 -0.90730
# 2             57        0           -0.57818                 -0.90199

# %% [markdown]
# #### cutoff
# These methods remove rows above or below a certain cutoff for a particular column

# %%
preselct.drop_rows_above_cutoff("s2_21h_%yield", 92)

# %%
preselct.x.head(3)
# Out:
#    s2_3.5h_%yield(avg)  s2_21h_%yield  s4_1h_%yield  s4_3.5h_%yield(avg)  \
# 0            55.500000             92             6            27.666667
# 1            36.333333             92             6            27.000000
# 2            19.666667             73             2            11.333333
#
#    s4_21h_%yield  virtual  nbo_N_oxamide_max  nbo_aryl_sub_=O_max_max
# 0             69        0           -0.59232                 -0.89851
# 1             65        0           -0.58780                 -0.90730
# 2             57        0           -0.57818                 -0.90199
